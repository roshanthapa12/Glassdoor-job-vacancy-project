# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7356\2151744951.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('project2.csv')
df
# Out:
#      index          Job Title               Salary Estimate  \
# 0        0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1        1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2        2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3        3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4        4     Data Scientist  $137K-$171K (Glassdoor est.)
# ..     ...                ...                           ...
# 667    667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668    668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669    669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670    670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671    671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              672 non-null    int64
#  1   Job Title          672 non-null    object
#  2   Salary Estimate    672 non-null    object
#  3   Job Description    672 non-null    object
#  4   Rating             672 non-null    float64
#  5   Company Name       672 non-null    object
#  6   Location           672 non-null    object
#  7   Headquarters       672 non-null    object
#  8   Size               672 non-null    object
#  9   Founded            672 non-null    int64
#  10  Type of ownership  672 non-null    object
#  11  Industry           672 non-null    object
#  12  Sector             672 non-null    object
#  13  Revenue            672 non-null    object
#  14  Competitors        672 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
df['Company Name']=df['Company Name'].str.split('\n',expand=True)[0]
df
# Out:
#      index          Job Title               Salary Estimate  \
# 0        0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1        1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2        2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3        3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4        4     Data Scientist  $137K-$171K (Glassdoor est.)
# ..     ...                ...                           ...
# 667    667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668    668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669    669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670    670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671    671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# ...

# %%
df['Size']= df['Size'].str.replace('to','-')
df
# Out:
#      index          Job Title               Salary Estimate  \
# 0        0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1        1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2        2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3        3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4        4     Data Scientist  $137K-$171K (Glassdoor est.)
# ..     ...                ...                           ...
# 667    667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668    668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669    669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670    670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671    671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# ...

# %%
df['Revenue']= df['Revenue'].str.replace('to','-')
df.head(4)
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating    Company Name  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1     Healthfirst
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2         ManTech
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8  Analysis Group
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5         INFICON
#
#         Location            Headquarters                    Size  Founded  \
# 0   New York, NY            New York, NY   1001 - 5000 employees     1993
# 1  Chantilly, VA             Herndon, VA  5001 - 10000 employees     1968
# ...

# %%
df['Competitors']= df['Competitors'].str.replace('-1','not found yet')
df.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# ...

# %%
df = df.drop('Job Description',axis =1)
df
# Out:
#      index          Job Title               Salary Estimate  Rating  \
# 0        0  Sr Data Scientist  $137K-$171K (Glassdoor est.)     3.1
# 1        1     Data Scientist  $137K-$171K (Glassdoor est.)     4.2
# 2        2     Data Scientist  $137K-$171K (Glassdoor est.)     3.8
# 3        3     Data Scientist  $137K-$171K (Glassdoor est.)     3.5
# 4        4     Data Scientist  $137K-$171K (Glassdoor est.)     2.9
# ..     ...                ...                           ...     ...
# 667    667     Data Scientist  $105K-$167K (Glassdoor est.)     3.6
# 668    668     Data Scientist  $105K-$167K (Glassdoor est.)    -1.0
# 669    669     Data Scientist  $105K-$167K (Glassdoor est.)    -1.0
# 670    670     Data Scientist  $105K-$167K (Glassdoor est.)     5.0
# 671    671     Data Scientist  $105K-$167K (Glassdoor est.)     2.7
#
#              Company Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# ...

# %%
df =df.drop('index',axis=1)
df
# Out:
#              Job Title               Salary Estimate  Rating  \
# 0    Sr Data Scientist  $137K-$171K (Glassdoor est.)     3.1
# 1       Data Scientist  $137K-$171K (Glassdoor est.)     4.2
# 2       Data Scientist  $137K-$171K (Glassdoor est.)     3.8
# 3       Data Scientist  $137K-$171K (Glassdoor est.)     3.5
# 4       Data Scientist  $137K-$171K (Glassdoor est.)     2.9
# ..                 ...                           ...     ...
# 667     Data Scientist  $105K-$167K (Glassdoor est.)     3.6
# 668     Data Scientist  $105K-$167K (Glassdoor est.)    -1.0
# 669     Data Scientist  $105K-$167K (Glassdoor est.)    -1.0
# 670     Data Scientist  $105K-$167K (Glassdoor est.)     5.0
# 671     Data Scientist  $105K-$167K (Glassdoor est.)     2.7
#
#              Company Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# ...

# %%
# deleting the row that conatains -1 in founded column
df =df[df['Headquarters']!= '-1']
df
# Out:
#              Job Title               Salary Estimate  Rating  \
# 0    Sr Data Scientist  $137K-$171K (Glassdoor est.)     3.1
# 1       Data Scientist  $137K-$171K (Glassdoor est.)     4.2
# 2       Data Scientist  $137K-$171K (Glassdoor est.)     3.8
# 3       Data Scientist  $137K-$171K (Glassdoor est.)     3.5
# 4       Data Scientist  $137K-$171K (Glassdoor est.)     2.9
# ..                 ...                           ...     ...
# 665     Data Scientist  $105K-$167K (Glassdoor est.)     3.8
# 666     Data Scientist  $105K-$167K (Glassdoor est.)     4.0
# 667     Data Scientist  $105K-$167K (Glassdoor est.)     3.6
# 670     Data Scientist  $105K-$167K (Glassdoor est.)     5.0
# 671     Data Scientist  $105K-$167K (Glassdoor est.)     2.7
#
#                 Company Name           Location            Headquarters  \
# 0                Healthfirst       New York, NY            New York, NY
# 1                    ManTech      Chantilly, VA             Herndon, VA
# ...

# %%
df.replace(-1,'unknown',inplace =True)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7356\954532140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace(-1,'unknown',inplace =True)
#              Job Title               Salary Estimate Rating  \
# 0    Sr Data Scientist  $137K-$171K (Glassdoor est.)    3.1
# 1       Data Scientist  $137K-$171K (Glassdoor est.)    4.2
# 2       Data Scientist  $137K-$171K (Glassdoor est.)    3.8
# 3       Data Scientist  $137K-$171K (Glassdoor est.)    3.5
# 4       Data Scientist  $137K-$171K (Glassdoor est.)    2.9
# ..                 ...                           ...    ...
# 665     Data Scientist  $105K-$167K (Glassdoor est.)    3.8
# 666     Data Scientist  $105K-$167K (Glassdoor est.)    4.0
# 667     Data Scientist  $105K-$167K (Glassdoor est.)    3.6
# ...

# %%
# Find the Data Scientist position job
data = df[df['Job Title'].str.contains(r'Data Scientist')]
data
# Out:
#              Job Title               Salary Estimate Rating  \
# 0    Sr Data Scientist  $137K-$171K (Glassdoor est.)    3.1
# 1       Data Scientist  $137K-$171K (Glassdoor est.)    4.2
# 2       Data Scientist  $137K-$171K (Glassdoor est.)    3.8
# 3       Data Scientist  $137K-$171K (Glassdoor est.)    3.5
# 4       Data Scientist  $137K-$171K (Glassdoor est.)    2.9
# ..                 ...                           ...    ...
# 665     Data Scientist  $105K-$167K (Glassdoor est.)    3.8
# 666     Data Scientist  $105K-$167K (Glassdoor est.)    4.0
# 667     Data Scientist  $105K-$167K (Glassdoor est.)    3.6
# 670     Data Scientist  $105K-$167K (Glassdoor est.)    5.0
# 671     Data Scientist  $105K-$167K (Glassdoor est.)    2.7
#
#                 Company Name           Location            Headquarters  \
# 0                Healthfirst       New York, NY            New York, NY
# 1                    ManTech      Chantilly, VA             Herndon, VA
# ...

# %%
# Find the Data Scientist position job that located in new york
data[data['Headquarters'].str.contains(r'New York, NY')]
# Out:
#                               Job Title               Salary Estimate  \
# 0                     Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 4                        Data Scientist  $137K-$171K (Glassdoor est.)
# 21      Data Scientist/Machine Learning  $137K-$171K (Glassdoor est.)
# 37                       Data Scientist   $75K-$131K (Glassdoor est.)
# 66                       Data Scientist   $79K-$131K (Glassdoor est.)
# 115                      Data Scientist   $99K-$132K (Glassdoor est.)
# 173  Senior Data Scientist - Algorithms  $101K-$165K (Glassdoor est.)
# 221     Data Scientist/Machine Learning   $71K-$123K (Glassdoor est.)
# 254                      Data Scientist   $90K-$124K (Glassdoor est.)
# 293                      Data Scientist  $141K-$225K (Glassdoor est.)
# 296                      Data Scientist  $141K-$225K (Glassdoor est.)
# 349                      Data Scientist  $122K-$146K (Glassdoor est.)
# ...

# %%
df['Industry']= df['Industry'].str.replace('-1','Unknown')
df.tail(10)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7356\1652614105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Industry']= df['Industry'].str.replace('-1','Unknown')
#           Job Title               Salary Estimate   Rating  \
# 659  Data Scientist  $105K-$167K (Glassdoor est.)      3.2
# 661  Data Scientist  $105K-$167K (Glassdoor est.)      3.6
# 662  Data Scientist  $105K-$167K (Glassdoor est.)      4.4
# 663  Data Scientist  $105K-$167K (Glassdoor est.)      4.1
# 664  Data Scientist  $105K-$167K (Glassdoor est.)  unknown
# 665  Data Scientist  $105K-$167K (Glassdoor est.)      3.8
# 666  Data Scientist  $105K-$167K (Glassdoor est.)      4.0
# 667  Data Scientist  $105K-$167K (Glassdoor est.)      3.6
# ...

# %%
df['Sector']= df['Sector'].str.replace('-1','Unknown')
df.tail(10)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7356\3191176927.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sector']= df['Sector'].str.replace('-1','Unknown')
#           Job Title               Salary Estimate   Rating  \
# 659  Data Scientist  $105K-$167K (Glassdoor est.)      3.2
# 661  Data Scientist  $105K-$167K (Glassdoor est.)      3.6
# 662  Data Scientist  $105K-$167K (Glassdoor est.)      4.4
# 663  Data Scientist  $105K-$167K (Glassdoor est.)      4.1
# 664  Data Scientist  $105K-$167K (Glassdoor est.)  unknown
# 665  Data Scientist  $105K-$167K (Glassdoor est.)      3.8
# 666  Data Scientist  $105K-$167K (Glassdoor est.)      4.0
# 667  Data Scientist  $105K-$167K (Glassdoor est.)      3.6
# ...
